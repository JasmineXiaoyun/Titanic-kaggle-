# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np

plt.rcParams['font.sans-serif']=['SimHei']

# %%
train_file=pd.read_csv("data/train.csv")

#把文字转换为数字
sex_mapping={"male":0,"female":1}
train_file.Sex=train_file.Sex.map(sex_mapping)

embarked_mapping={"S":0,"C":1,"Q":2}
train_file.Embarked=train_file.Embarked.map(embarked_mapping)

train_file.loc[(train_file.Cabin.notnull()),'Cabin']=1
train_file.loc[(train_file.Cabin.isnull()),'Cabin']=0
 
#去掉不用的两列
train_data=train_file.drop(columns=['Name','Ticket'])

#把feature缺失值填为-1
train_data=train_data.fillna(-1)


#拆分训练集测试集
train_data_array=np.array(train_data)
print(train_data_array)
print(" ")
np.random.shuffle(train_data_array)#随机打乱
print(train_data_array)
print(" ")
train_set=train_data_array[:int(0.8*len(train_data))]
test_set=train_data_array[int(0.8*len(train_data)):]
print(train_set[:100])


#将array转为dataframe
df_train=pd.DataFrame(train_set,columns=['PassengerId','Survived','Pclass','Sex','Age','SibSp','Parch','Fare','Cabin','Embarked'])
df_test=pd.DataFrame(test_set,columns=['PassengerId','Survived','Pclass','Sex','Age','SibSp','Parch','Fare','Cabin','Embarked'])
#print(df_train)
#print(df_test)

df_train_y=df_train.loc[:,'Survived']
#print(df_train_y)
df_train_x=df_train.drop(['Survived'],axis=1)
#print(df_train_x)
df_test_y=df_test.loc[:,'Survived']
#print(df_test_y)
df_test_x=df_test.drop(['Survived'],axis=1)
#print(df_test_x)
# Out:
# [[  1.       0.       3.     ...   7.25     0.       0.    ]
#  [  2.       1.       1.     ...  71.2833   1.       1.    ]
#  [  3.       1.       3.     ...   7.925    0.       0.    ]
#  ...
#  [889.       0.       3.     ...  23.45     0.       0.    ]
#  [890.       1.       1.     ...  30.       1.       1.    ]
#  [891.       0.       3.     ...   7.75     0.       2.    ]]
#
# [[212.       1.       2.     ...  21.       0.       0.    ]
#  [519.       1.       2.     ...  26.       0.       0.    ]
#  [746.       0.       1.     ...  71.       1.       0.    ]
#  ...
#  [692.       1.       3.     ...  13.4167   0.       1.    ]
#  [316.       1.       3.     ...   7.8542   0.       0.    ]
#  [507.       1.       2.     ...  26.       0.       0.    ]]
#
# [[212.       1.       2.       1.      35.       0.       0.      21.
#     0.       0.    ]
#  [519.       1.       2.       1.      36.       1.       0.      26.
#     0.       0.    ]
#  [746.       0.       1.       0.      70.       1.       1.      71.
#     1.       0.    ]
#  [276.       1.       1.       1.      63.       1.       0.      77.9583
#     1.       0.    ]
#  [878.       0.       3.       0.      19.       0.       0.       7.8958
#     0.       0.    ]
#  [750.       0.       3.       0.      31.       0.       0.       7.75
#     0.       2.    ]
#  [275.       1.       3.       1.      -1.       0.       0.       7.75
#     0.       2.    ]
#  [231.       1.       1.       1.      35.       1.       0.      83.475
#     1.       0.    ]
#  [ 50.       0.       3.       1.      18.       1.       0.      17.8
#     0.       0.    ]
#  [216.       1.       1.       1.      31.       1.       0.     113.275
#     1.       1.    ]
#  [ 65.       0.       1.       0.      -1.       0.       0.      27.7208
#     0.       1.    ]
#  [ 21.       0.       2.       0.      35.       0.       0.      26.
#     0.       0.    ]
#  [776.       0.       3.       0.      18.       0.       0.       7.75
#     0.       0.    ]
#  [630.       0.       3.       0.      -1.       0.       0.       7.7333
#     0.       2.    ]
#  [322.       0.       3.       0.      27.       0.       0.       7.8958
#     0.       0.    ]
#  [453.       0.       1.       0.      30.       0.       0.      27.75
#     1.       1.    ]
#  [499.       0.       1.       1.      25.       1.       2.     151.55
#     1.       0.    ]
#  [547.       1.       2.       1.      19.       1.       0.      26.
#     0.       0.    ]
#  [626.       0.       1.       0.      61.       0.       0.      32.3208
#     1.       0.    ]
#  [608.       1.       1.       0.      27.       0.       0.      30.5
#     0.       0.    ]
#  [ 20.       1.       3.       1.      -1.       0.       0.       7.225
#     0.       1.    ]
#  [709.       1.       1.       1.      22.       0.       0.     151.55
#     0.       0.    ]
#  [532.       0.       3.       0.      -1.       0.       0.       7.2292
#     0.       1.    ]
#  [350.       0.       3.       0.      42.       0.       0.       8.6625
#     0.       0.    ]
#  [195.       1.       1.       1.      44.       0.       0.      27.7208
#     1.       1.    ]
#  [149.       0.       2.       0.      36.5      0.       2.      26.
#     1.       0.    ]
#  [881.       1.       2.       1.      25.       0.       1.      26.
#     0.       0.    ]
#  [  3.       1.       3.       1.      26.       0.       0.       7.925
#     0.       0.    ]
#  [261.       0.       3.       0.      -1.       0.       0.       7.75
#     0.       2.    ]
#  [769.       0.       3.       0.      -1.       1.       0.      24.15
#     0.       2.    ]
#  [189.       0.       3.       0.      40.       1.       1.      15.5
#     0.       2.    ]
#  [791.       0.       3.       0.      -1.       0.       0.       7.75
#     0.       2.    ]
#  [865.       0.       2.       0.      24.       0.       0.      13.
#     0.       0.    ]
#  [735.       0.       2.       0.      23.       0.       0.      13.
#     0.       0.    ]
#  [132.       0.       3.       0.      20.       0.       0.       7.05
#     0.       0.    ]
#  [433.       1.       2.       1.      42.       1.       0.      26.
#     0.       0.    ]
#  [123.       0.       2.       0.      32.5      1.       0.      30.0708
#     0.       1.    ]
#  [150.       0.       2.       0.      42.       0.       0.      13.
#     0.       0.    ]
#  [389.       0.       3.       0.      -1.       0.       0.       7.7292
#     0.       2.    ]
#  [ 36.       0.       1.       0.      42.       1.       0.      52.
#     0.       0.    ]
#  [698.       1.       3.       1.      -1.       0.       0.       7.7333
#     0.       2.    ]
#  [413.       1.       1.       1.      33.       1.       0.      90.
#     1.       2.    ]
#  [330.       1.       1.       1.      16.       0.       1.      57.9792
#     1.       1.    ]
#  [ 93.       0.       1.       0.      46.       1.       0.      61.175
#     1.       0.    ]
#  [484.       1.       3.       1.      63.       0.       0.       9.5875
#     0.       0.    ]
#  [100.       0.       2.       0.      34.       1.       0.      26.
#     0.       0.    ]
#  [ 64.       0.       3.       0.       4.       3.       2.      27.9
#     0.       0.    ]
#  [705.       0.       3.       0.      26.       1.       0.       7.8542
#     0.       0.    ]
#  [131.       0.       3.       0.      33.       0.       0.       7.8958
#     0.       1.    ]
#  [ 82.       1.       3.       0.      29.       0.       0.       9.5
#     0.       0.    ]
#  [206.       0.       3.       1.       2.       0.       1.      10.4625
#     1.       0.    ]
#  [294.       0.       3.       1.      24.       0.       0.       8.85
#     0.       0.    ]
#  [ 52.       0.       3.       0.      21.       0.       0.       7.8
#     0.       0.    ]
#  [ 72.       0.       3.       1.      16.       5.       2.      46.9
#     0.       0.    ]
#  [324.       1.       2.       1.      22.       1.       1.      29.
#     0.       0.    ]]

# %%
from sklearn.ensemble import AdaBoostClassifier
clf=AdaBoostClassifier(n_estimators=10)#10个弱分类器
clf.fit(df_train_x,df_train_y)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=10, random_state=None)

# %%
from sklearn.metrics import accuracy_score
predicted_classes_train=clf.predict(df_train_x)
accuracy_train=accuracy_score(df_train_y.values,predicted_classes_train)
print(accuracy_train)
predicted_classes_test=clf.predict(df_test_x)
accuracy_test=accuracy_score(df_test_y.values,predicted_classes_test)
print(accuracy_test)
# Out:
# 0.8033707865168539
# 0.8212290502793296
